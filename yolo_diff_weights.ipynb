# %%
import torch
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
# !pip install ultralytics
from ultralytics import YOLO
import glob
import os
import random
import shutil
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.7/611.7 kB 14.1 MB/s eta 0:00:00
# ...

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA A100-SXM4-40GB'

# %%
random.seed(42)

# %%
models = [YOLO('yolov8l.pt'), YOLO('yolov8x.pt')]
# Out:
# ...
# 100%|██████████| 83.7M/83.7M [00:01<00:00, 74.6MB/s]
# ...
# 100%|██████████| 131M/131M [00:01<00:00, 74.2MB/s]

# %%
colab_path = "/content/drive/MyDrive/FYP Google Colab/"

# %%
for model in models:
  model.train(data=os.path.join(colab_path,'synthetic_and_real/train_yolo.yaml'), epochs=100, device=0,batch=32,optimizer='Adam',lr0=0.001)
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
# Move files
import shutil
shutil.copytree('/content/runs/detect/train2', '/content/drive/My Drive/FYP Google Colab/synthetic_and_real/train_xlarge')
# Out:
# '/content/drive/My Drive/FYP Google Colab/synthetic_and_real/train_xlarge'

# %%
nano_path = '/content/drive/My Drive/FYP Google Colab/synthetic_and_real/train_nano/'
small_path = '/content/drive/My Drive/FYP Google Colab/synthetic_and_real/train_small/'
medium_path = '/content/drive/My Drive/FYP Google Colab/synthetic_and_real/train_medium/'
large_path = '/content/drive/My Drive/FYP Google Colab/synthetic_and_real/train_large/'
xlarge_path = '/content/drive/My Drive/FYP Google Colab/synthetic_and_real/train_xlarge/'

# %%
# !yolo detect val model='/content/drive/My Drive/FYP Google Colab/synthetic_and_real/train_nano/weights/best.pt' data='/content/drive/MyDrive/FYP Google Colab/val.yaml' device=0
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/FYP Google Colab/test.cache... 29 images, 15 backgrounds, 0 corrupt: 100% 29/29 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.01s/it]
#                    all         29         14      0.923      0.857      0.913      0.586
# Speed: 2.2ms preprocess, 22.5ms inference, 0.0ms loss, 4.9ms postprocess per image
# Results saved to runs/detect/val4

# %%
# !yolo detect val model='/content/drive/My Drive/FYP Google Colab/synthetic_and_real/train_small/weights/best.pt' data='/content/drive/MyDrive/FYP Google Colab/val.yaml' device=0
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/FYP Google Colab/test.cache... 29 images, 15 backgrounds, 0 corrupt: 100% 29/29 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.48it/s]
#                    all         29         14      0.856      0.929      0.878       0.55
# Speed: 2.4ms preprocess, 24.1ms inference, 0.0ms loss, 5.7ms postprocess per image
# Results saved to runs/detect/val5

# %%
# !yolo detect val model='/content/drive/My Drive/FYP Google Colab/synthetic_and_real/train_medium/weights/best.pt' data='/content/drive/MyDrive/FYP Google Colab/val.yaml' device=0
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/FYP Google Colab/test.cache... 29 images, 15 backgrounds, 0 corrupt: 100% 29/29 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.43it/s]
#                    all         29         14      0.881      0.857      0.965      0.507
# Speed: 2.7ms preprocess, 26.0ms inference, 0.0ms loss, 4.9ms postprocess per image
# Results saved to runs/detect/val6

# %%
# !yolo detect val model='/content/drive/My Drive/FYP Google Colab/synthetic_and_real/train_large/weights/best.pt' data='/content/drive/MyDrive/FYP Google Colab/val.yaml' device=0
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 268 layers, 43607379 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/FYP Google Colab/test.cache... 29 images, 15 backgrounds, 0 corrupt: 100% 29/29 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.46it/s]
#                    all         29         14       0.49      0.929      0.686      0.361
# Speed: 2.7ms preprocess, 24.6ms inference, 0.0ms loss, 6.7ms postprocess per image
# Results saved to runs/detect/val7

# %%
# !yolo detect val model='/content/drive/My Drive/FYP Google Colab/synthetic_and_real/train_xlarge/weights/best.pt' data='/content/drive/MyDrive/FYP Google Colab/val.yaml' device=0
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 268 layers, 68124531 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/FYP Google Colab/test.cache... 29 images, 15 backgrounds, 0 corrupt: 100% 29/29 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.45it/s]
#                    all         29         14      0.884      0.714       0.83      0.425
# Speed: 2.2ms preprocess, 25.9ms inference, 0.0ms loss, 6.5ms postprocess per image
# Results saved to runs/detect/val8

# %%
# !yolo detect predict model='/content/drive/My Drive/FYP Google Colab/synthetic_and_real/train_nano/weights/best.pt' source='/content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4'
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
#
# video 1/1 (1/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 128.6ms
# video 1/1 (2/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 1 lesion, 7.9ms
# video 1/1 (3/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 1 lesion, 7.1ms
# video 1/1 (4/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 7.5ms
# video 1/1 (5/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 11.0ms
# video 1/1 (6/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 7.1ms
# video 1/1 (7/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 10.3ms
# ...

# %%
# !yolo detect predict model='/content/drive/My Drive/FYP Google Colab/synthetic_and_real/train_small/weights/best.pt' source='/content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4'
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# video 1/1 (1/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 143.7ms
# video 1/1 (2/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 7.7ms
# video 1/1 (3/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 7.4ms
# video 1/1 (4/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 7.7ms
# video 1/1 (5/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 7.3ms
# video 1/1 (6/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 7.4ms
# video 1/1 (7/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 7.2ms
# ...

# %%
# !yolo detect predict model='/content/drive/MyDrive/FYP Google Colab/synthetic_and_real/train_medium/weights/best.pt' source='/content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4'
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients
#
# video 1/1 (1/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 1 lesion, 153.1ms
# video 1/1 (2/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 1 lesion, 10.1ms
# video 1/1 (3/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 1 lesion, 9.3ms
# video 1/1 (4/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 1 lesion, 9.5ms
# video 1/1 (5/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 1 lesion, 9.3ms
# video 1/1 (6/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 9.3ms
# video 1/1 (7/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 9.3ms
# ...

# %%
# !yolo detect predict model='/content/drive/MyDrive/FYP Google Colab/synthetic_and_real/train_large/weights/best.pt' source='/content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4'
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 268 layers, 43607379 parameters, 0 gradients
#
# video 1/1 (1/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 141.5ms
# video 1/1 (2/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 11.4ms
# video 1/1 (3/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 12.7ms
# video 1/1 (4/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 11.0ms
# video 1/1 (5/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 11.0ms
# video 1/1 (6/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 11.8ms
# video 1/1 (7/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 14.3ms
# ...

# %%
# !yolo detect predict model='/content/drive/MyDrive/FYP Google Colab/synthetic_and_real/train_xlarge/weights/best.pt' source='/content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4'
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 268 layers, 68124531 parameters, 0 gradients
#
# video 1/1 (1/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 137.4ms
# video 1/1 (2/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 12.6ms
# video 1/1 (3/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 13.1ms
# video 1/1 (4/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 12.5ms
# video 1/1 (5/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 12.5ms
# video 1/1 (6/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 12.5ms
# video 1/1 (7/4355) /content/drive/MyDrive/FYP Google Colab/ash_video_001.mp4: 384x640 (no detections), 12.5ms
# ...
